# %% [markdown]
# ## seaborn

# %% [markdown]
# ##### >import seaborn as sb
# ##### >df=sb.load_dataset('tips')
# ##### >print df.head()

# %%
#seaborn.color_palette(palette=None,n_colors=None,desat=None).
#available seaborn platte names:deep,muted,bright,pastel,dark,colorblind.
#seaborn plots--->histogram plot,bar plot,scatter,box,joint,factedgrid,
#--facted,distrubution,voilon,kole,pair,relation,swarm.

# %%
import seaborn as sns

# %%
dir(sns)
# Out:
# ['FacetGrid',
#  'JointGrid',
#  'PairGrid',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_orig_rc_params',
#  'algorithms',
#  'axes_style',
#  'axisgrid',
#  'barplot',
#  'blend_palette',
#  'boxenplot',
#  'boxplot',
#  'categorical',
#  'catplot',
#  'choose_colorbrewer_palette',
#  'choose_cubehelix_palette',
#  'choose_dark_palette',
#  'choose_diverging_palette',
#  'choose_light_palette',
#  'clustermap',
#  'cm',
#  'color_palette',
#  'colors',
#  'countplot',
#  'crayon_palette',
#  'crayons',
#  'cubehelix_palette',
#  'dark_palette',
#  'desaturate',
#  'despine',
#  'distplot',
#  'distributions',
#  'diverging_palette',
#  'dogplot',
#  'external',
#  'factorplot',
#  'get_dataset_names',
#  'heatmap',
#  'hls_palette',
#  'husl_palette',
#  'jointplot',
#  'kdeplot',
#  'light_palette',
#  'lineplot',
#  'lmplot',
#  'load_dataset',
#  'lvplot',
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.random.rand(20)
y=np.random.rand(20)
plt.plot(x,y,'ko',alpha=0.1,linewidth=2,markersize=20)
#legend.loc("right")

# %%
help(sns.set)
# Out:
# Help on function set in module seaborn.rcmod:
#
# set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, rc=None)
#     Set aesthetic parameters in one step.
#
#     Each set of parameters can be set directly or temporarily, see the
#     referenced functions below for more information.
#
#     Parameters
#     ----------
#     context : string or dict
#         Plotting context parameters, see :func:`plotting_context`
#     style : string or dict
#         Axes style parameters, see :func:`axes_style`
#     palette : string or sequence
#         Color palette, see :func:`color_palette`
#     font : string
#         Font family, see matplotlib font manager.
#     font_scale : float, optional
#         Separate scaling factor to independently scale the size of the
#         font elements.
#     color_codes : bool
#         If ``True`` and ``palette`` is a seaborn palette, remap the shorthand
# ...

# %%
sns.set(color_codes=True)
plt.plot(x,y)

# %%
sns.set(palette="muted")
plt.plot(x,y)

# %%
import pandas as pd
data=pd.DataFrame({'x':[2,3,5,6],'y':[4,3,88,99]})
data
# Out:
#    x   y
# 0  2   4
# 1  3   3
# 2  5  88
# 3  6  99

# %%
plt.plot(data['x'],data['y'],'rs')

# %% [markdown]
# ### relation plot-high level functioning plot
# #### scatter
# #### line

# %%
sns.set()
sns.relplot(x='x',y='y',data=data)

# %%
sns.set()
sns.relplot(x='x',y='y',data=data,kind='line')

# %%
sns.set()
sns.relplot(x='x',y='y',data=data,legend='brief')

# %%
sns.set()
sns.relplot(x='x',y='y',data=data,facet_kws=None)

# %%
sns.set()
sns.relplot(x='x',y='y',data=data,kind='line',size=0.5,markers=['x','s'])

# %%
sns.set(style="darkgrid")
sns.relplot(x='x',y='y',hue='y',data=data,size=0.5,markers=['*','s'])

# %%
##loading a datasets
#import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'iris',
#  'mpg',
#  'planets',
#  'tips',
#  'titanic']

# %%
df=sns.load_dataset('flights')
df.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df=sns.load_dataset('tips')
df.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
sns.relplot(x="total_bill",y="day",data=df)

# %%
sns.relplot(x="total_bill",y="day",data=df,hue="tip")

# %%
sns.relplot(x="total_bill",y="size",data=df,hue="tip",kind="line")

# %%
m=sns.load_dataset('iris')
m.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.relplot(x="sepal_length",y="petal_length",data=m)

# %%
sns.relplot(x="sepal_length",y="petal_length",data=m,hue="petal_width")

# %%
sns.relplot(x="sepal_length",y="petal_length",data=m,hue="petal_width",kind="line")

# %%
df=sns.load_dataset('flights')
df
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# 5    1949       June         135
# 6    1949       July         148
# 7    1949     August         148
# 8    1949  September         136
# 9    1949    October         119
# 10   1949   November         104
# 11   1949   December         118
# 12   1950    January         115
# 13   1950   February         126
# 14   1950      March         141
# 15   1950      April         135
# 16   1950        May         125
# 17   1950       June         149
# 18   1950       July         170
# 19   1950     August         170
# 20   1950  September         158
# 21   1950    October         133
# 22   1950   November         114
# 23   1950   December         140
# 24   1951    January         145
# 25   1951   February         150
# 26   1951      March         178
# ...

# %%
# Out:
#   File "<ipython-input-76-40c5c93bca4b>", line 1
#     sns.
#         ^
# SyntaxError: invalid syntax

# %%
m=sns.load_dataset('iris')
m.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
m["species"].value_counts()
# Out:
# versicolor    50
# setosa        50
# virginica     50
# Name: species, dtype: int64

# %%
sns.relplot(x="sepal_width",y="petal_width",data=m)

# %%
sns.relplot(x="sepal_width",y="petal_width",data=m,hue="species",col="species")

# %%
df=sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# 10        10.27  1.71    Male     No   Sun  Dinner     2
# 11        35.26  5.00  Female     No   Sun  Dinner     4
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 13        18.43  3.00    Male     No   Sun  Dinner     4
# 14        14.83  3.02  Female     No   Sun  Dinner     2
# ...

# %%
sns.relplot("total_bill",y="tip",data=df,style="smoker",size="size",col="time")

# %%
#linear regression plot
sns.lmplot(x='total_bill',y="tip",data=df)

# %%
#categorial data plot
#catplot-->the plot catagorizing the data...
                         #1.SWARM PLOT,
                         #2.SCATTER,
                         #3.BAR PLOT,
                         #4.VIOLIN PLOT

# %%
sns.catplot(x="species",y="petal_length",data=m)

# %%
sns.catplot(x="species",y="petal_length",hue="sepal_width",data=m)

# %%
sns.catplot(x="species",y="petal_length",hue="sepal_width",data=m,kind="swarm")

# %%
sns.catplot(x="species",y="petal_length",hue="sepal_width",data=m,kind="bar")

# %%
sns.catplot(x="species",y="petal_length",hue="sepal_width",data=m,kind="violin")

# %%
##box plot
f,axs=plt.subplots(1,2)
sns.boxplot(x="species",y="sepal_length",data=m,ax=axs[0])
sns.scatterplot(x="species",y="sepal_length",data=m,ax=axs[1])

# %%
sns.boxplot(x="total_bill",y="tip",data=df)

# %%
sns.swarmplot(x="total_bill",y="day",data=df)

# %%
## visualisation of dataset
##  jointplot
##kde-kernal density
# hex
#scatter
#reg

# %%
sns.jointplot(x="total_bill",y="tip",data=df)

# %%
sns.jointplot(x="total_bill",y="tip",data=df,kind="kde")

# %%
sns.jointplot(x="total_bill",y="tip",hue="smoker",data=df,kind="kde")

# %%
sns.jointplot(x="total_bill",y="tip",data=df,kind="hex")

# %%
sns.jointplot(x="total_bill",y="tip",data=df,kind="reg",color='g',height=3.5,ratio=5)

# %%
#pairplot
sns.pairplot(data=m)

# %%
sns.pairplot(data=m,hue="species",palette='muted')

# %%
sns.pairplot(data=m,hue="species",markers=["x","s","D"])

# %%
sns.pairplot(m,vars=["sepal_width","sepal_length","petal_width","petal_length"])

# %%
sns.pairplot(m,diag_kind="kde")

# %%
sns.pairplot(m,diag_kind="kde",markers="+")

# %%
x=np.random.rand(50)
sns.distplot(x)

# %%
#facetgrid plot
ff=sns.FacetGrid(m,col="species")
ff.map(plt.hist,"petal_length")

# %%
#tipstatus
n=sns.FacetGrid(df,col="size")
n.map(plt.hist,"tip")

# %%
#pairgrid
pp=sns.PairGrid(m)
pp.map(plt.scatter)
